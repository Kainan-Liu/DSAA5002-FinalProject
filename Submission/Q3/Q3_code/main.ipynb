# %%
from run import seed_everything, main

# %%
seed_everything(random_state=42)
main(num_classes=15, epochs=1, batch_size=2, lr=2e-5, test_file="../../Data/Q3/test_video/")
# Out:
# ======================================================
# Begin Fine-tuning on Our weather dataset
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 seed_everything(random_state=42)
# ----> 2 main(num_classes=15, epochs=1, batch_size=2, lr=2e-5, test_file="../../Data/Q3/test_video/")
#
# File c:\Users\lenovo\Desktop\HKUSTGZ-PG\Course-project\DSAA-5002\Final-Project\src\Q3\run.py:52, in main(num_classes, epochs, batch_size, lr, test_file)
#      49 label = label.to(device=device)
#      51 # forward
# ---> 52 pred = model(data)
#      54 # backward
#      55 loss = criterion(pred, label)
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\lenovo\Desktop\HKUSTGZ-PG\Course-project\DSAA-5002\Final-Project\src\Q3\model.py:54, in Swin3d_Wrapper.forward(self, x)
#      53 def forward(self, x):
# ---> 54     return self.model(x)
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torchvision\models\video\swin_transformer.py:466, in SwinTransformer3d.forward(self, x)
#     464 x = self.patch_embed(x)  # B _T _H _W C
#     465 x = self.pos_drop(x)
# --> 466 x = self.features(x)  # B _T _H _W C
#     467 x = self.norm(x)
#     468 x = x.permute(0, 4, 1, 2, 3)  # B, C, _T, _H, _W
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torchvision\models\swin_transformer.py:453, in SwinTransformerBlock.forward(self, x)
#     452 def forward(self, x: Tensor):
# --> 453     x = x + self.stochastic_depth(self.attn(self.norm1(x)))
#     454     x = x + self.stochastic_depth(self.mlp(self.norm2(x)))
#     455     return x
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torchvision\models\video\swin_transformer.py:303, in ShiftedWindowAttention3d.forward(self, x)
#     299 window_size, shift_size = _get_window_and_shift_size(shift_size, size_dhw, window_size)
#     301 relative_position_bias = self.get_relative_position_bias(window_size)
# --> 303 return shifted_window_attention_3d(
#     304     x,
#     305     self.qkv.weight,
#     306     self.proj.weight,
#     307     relative_position_bias,
#     308     window_size,
#     309     self.num_heads,
#     310     shift_size=shift_size,
#     311     attention_dropout=self.attention_dropout,
#     312     dropout=self.dropout,
#     313     qkv_bias=self.qkv.bias,
#     314     proj_bias=self.proj.bias,
#     315     training=self.training,
#     316 )
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torchvision\models\video\swin_transformer.py:198, in shifted_window_attention_3d(input, qkv_weight, proj_weight, relative_position_bias, window_size, num_heads, shift_size, attention_dropout, dropout, qkv_bias, proj_bias, training)
#     195     attn = attn + attn_mask.unsqueeze(1).unsqueeze(0)
#     196     attn = attn.view(-1, num_heads, x.size(1), x.size(1))
# --> 198 attn = F.softmax(attn, dim=-1)
#     199 attn = F.dropout(attn, p=attention_dropout, training=training)
#     201 x = attn.matmul(v).transpose(1, 2).reshape(x.size(0), x.size(1), c)
#
# File d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\torch\nn\functional.py:1843, in softmax(input, dim, _stacklevel, dtype)
#    1841     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1842 if dtype is None:
# -> 1843     ret = input.softmax(dim)
#    1844 else:
#    1845     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:
