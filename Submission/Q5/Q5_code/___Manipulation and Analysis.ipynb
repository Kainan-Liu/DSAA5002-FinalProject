# %%
import pandas as pd
import os
os.chdir("../../Data/Q5/")

# %% [markdown]
# ## Load Data

# %%
train_data = pd.read_excel("./Q5_train.xlsx")
test_data = pd.read_csv("./Q5_test.csv")

# %% [markdown]
# ## Data Manipulation and Analysis
# - Num of samples
# - Missing Value Detection
# - Distribution

# %% [markdown]
# ### Number of training sample

# %%
train_num = len(train_data)
train_num
# Out:
# 159256

# %% [markdown]
# ### Missing Value Detection

# %%
train_data.isna().any()
# Out:
# id                     False
# age                    False
# height(cm)              True
# weight(kg)             False
# waist(cm)               True
# eyesight(left)          True
# eyesight(right)         True
# hearing(left)          False
# hearing(right)          True
# systolic               False
# relaxation             False
# fasting blood sugar    False
# Cholesterol            False
# triglyceride           False
# HDL                    False
# LDL                    False
# hemoglobin             False
# Urine protein           True
# serum creatinine       False
# AST                    False
# ALT                    False
# Gtp                    False
# dental caries          False
# smoking                False
# dtype: bool

# %%
## Drop the NA in the training data
train_data.dropna(axis=0, inplace=True)
train_data.head()
# Out:
#    id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0   55       165.0          60       81.0             0.5
# 1   1   70       165.0          65       89.0             0.6
# 2   2   20       170.0          75       81.0             0.4
# 3   3   35       180.0          95      105.0             1.5
# 4   4   30       165.0          60       80.5             1.5
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  LDL  \
# 0              0.6              1             1.0       135  ...   40   75
# 1              0.7              2             2.0       146  ...   57  126
# 2              0.5              1             1.0       118  ...   45   93
# 3              1.2              1             1.0       131  ...   38  102
# 4              1.0              1             1.0       121  ...   44   93
#
#    hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# ...

# %%
train_data.var(axis="rows").sort_values()
# Out:
# hearing(right)         2.279696e-02
# hearing(left)          2.336364e-02
# serum creatinine       3.237491e-02
# Urine protein          1.202260e-01
# eyesight(right)        1.549680e-01
# dental caries          1.590846e-01
# eyesight(left)         1.609193e-01
# smoking                2.461541e-01
# hemoglobin             2.046216e+00
# height(cm)             7.806539e+01
# waist(cm)              8.008402e+01
# relaxation             8.100408e+01
# AST                    9.235558e+01
# age                    1.402979e+02
# weight(kg)             1.578561e+02
# systolic               1.617646e+02
# HDL                    1.953425e+02
# fasting blood sugar    2.326450e+02
# ALT                    3.367029e+02
# LDL                    7.838664e+02
# Cholesterol            8.088124e+02
# Gtp                    9.812823e+02
# triglyceride           4.398388e+03
# id                     2.115335e+09
# dtype: float64

# %%
len(train_data)
# Out:
# 124413

# %% [markdown]
# ### Smoke or not smoke

# %%
train_data.loc[:, "smoking"].value_counts()
# Out:
# smoking
# 0    69924
# 1    54489
# Name: count, dtype: int64

# %% [markdown]
# ## Test data

# %%
test_data.head()
# Out:
#        id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0  159256   40         165          70       84.0             1.2
# 1  159257   80         160          60       93.0             1.0
# 2  159258   60         170          70       86.5             0.6
# 3  159259   40         160          50       67.0             0.3
# 4  159260   40         170          75       89.4             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  \
# 0              1.2              1               1       130  ...
# 1              1.0              2               2       144  ...
# 2              0.7              1               1       117  ...
# 3              0.4              1               1       116  ...
# 4              0.9              1               1       132  ...
#
#    triglyceride  HDL  LDL  hemoglobin  Urine protein  serum creatinine  AST  \
# 0           186   49  115        14.2              1               0.9   19
# ...

# %%
from model import xgboost_wrapper
xgboost_wrapper(data_dir="../../Data/Q5/", dropna=True, remove_low_variance=4)
# Out:
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400}
# Validation Accuracy: 0.7856
# AUC: 0.8673800644743254
# ...
# Submit successfully!
# ...

# %%
xgboost_wrapper(data_dir="../../Data/Q5/", dropna=False)
# Out:
# Best Parameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 400}
# Validation Accuracy: 0.7786
# AUC: 0.8638430953248801
# ...
# Submit successfully!
# ...

# %%
xgboost_wrapper(data_dir="../../Data/Q5/", dropna=True)
# Out:
# Best Parameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 400}
# Validation Accuracy: 0.7874
# AUC: 0.8700225776693853
# ...
# Submit successfully!
# ...
