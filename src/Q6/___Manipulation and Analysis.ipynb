# %%
import pandas as pd

# %%
data = pd.read_csv("../../Data/Q6/Bank_Customer.csv")

# %%
data
# Out:
#         TransactionID CustomerID CustomerDateOfBirth CustGender  \
# 0                  T1   C5841053             10/1/94          F
# 1                  T2   C2142763              4/4/57          M
# 2                  T3   C4417068            26/11/96          F
# 3                  T4   C5342380             14/9/73          F
# 4                  T5   C9031234             24/3/88          F
# ...               ...        ...                 ...        ...
# 1048562      T1048563   C8020229              8/4/90          M
# 1048563      T1048564   C6459278             20/2/92          M
# 1048564      T1048565   C6412354             18/5/89          M
# 1048565      T1048566   C6420483             30/8/78          M
# 1048566      T1048567   C8337524              5/3/84          M
#
#           CustLocation  CustAccountBalance TransactionDate  TransactionTime  \
# 0           JAMSHEDPUR            17819.05       2002/8/16           143207
# ...

# %%
data.isna().any()
# Out:
# TransactionID              False
# CustomerID                 False
# CustomerDateOfBirth         True
# CustGender                  True
# CustLocation                True
# CustAccountBalance          True
# TransactionDate            False
# TransactionTime            False
# TransactionAmount (INR)    False
# dtype: bool

# %%
data.dropna(axis=0, inplace=True)

# %%
data
# Out:
#         TransactionID CustomerID CustomerDateOfBirth CustGender  \
# 0                  T1   C5841053             10/1/94          F
# 1                  T2   C2142763              4/4/57          M
# 2                  T3   C4417068            26/11/96          F
# 3                  T4   C5342380             14/9/73          F
# 4                  T5   C9031234             24/3/88          F
# ...               ...        ...                 ...        ...
# 1048562      T1048563   C8020229              8/4/90          M
# 1048563      T1048564   C6459278             20/2/92          M
# 1048564      T1048565   C6412354             18/5/89          M
# 1048565      T1048566   C6420483             30/8/78          M
# 1048566      T1048567   C8337524              5/3/84          M
#
#           CustLocation  CustAccountBalance TransactionDate  TransactionTime  \
# 0           JAMSHEDPUR            17819.05       2002/8/16           143207
# ...

# %%
from sklearn.cluster import KMeans
kmeans_model =KMeans(n_clusters=8, n_init="auto", random_state=42)
kmeans_model.fit(data)
predict_label = kmeans_model.labels_
print(predict_label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9976\4064547623.py in ?()
#       1 from sklearn.cluster import KMeans
#       2 kmeans_model =KMeans(n_clusters=8, n_init="auto", random_state=42)
# ----> 3 kmeans_model.fit(data)
#       4 predict_label = kmeans_model.labels_
#       5 print(predict_label)
#
# d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# d:\Program\Anaconda3\envs\bioinfo\lib\site-packages\sklearn\cluster\_kmeans.py in ?(self, X, y, sample_weight)
#    1467         -------
#    1468         self : object
# ...
